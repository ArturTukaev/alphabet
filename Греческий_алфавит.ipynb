# %% [markdown]
# #Греческий алфавит
#
# **Заглавная** | **Строчная** | **Название**
# ---|---|:---
# Α|α|Альфа
# Β|β|Бета
# Γ|γ|Гамма
# Δ|δ|Дельта
# Ε|ϵ|Эпсилон
# Ζ|ζ|Дзета
# Η|η|Эта
# Θ|θ|Тета
# Ι|ι|Йота
# Κ|κ|Каппа
# Λ|λ|Лямбда
# Μ|μ|Мю
# Ν|ν|Ню
# Ξ|ξ|Кси
# Ο|ο|Омикрон
# Π|π|Пи
# R|ρ|Ро
# Σ|σ|Сигма
# T|τ|Тау
# Υ|υ|Ипсилон
# Φ|ϕ|Фи
# X|χ|Хи
# Ψ|ψ|Пси
# Ω|ω|Омега
#
# ##Формула в тексте
#
# $f(x)=\frac{1}{σ \sqrt {2π}} e^{-{\frac{1}{2}}(\frac{x - μ}{σ})^2}$
#
# ###Формула в отдельной строке
#
# $$f(x)=\frac{1}{σ \sqrt {2π}} e^{-{\frac{1}{2}}(\frac{x - μ}{σ})^2}$$
